# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
monthly_costs_years = pd.read_csv('../Brianne/Resources/monthly_costs_years.csv')
monthly_costs_years
# Out:
#       MONTHLY HOUSING COSTS 2022 Occupied housing units  \
# 0            Less than $300                     296,456
# 1              $300 to $499                     559,578
# 2              $500 to $799                   1,039,849
# 3              $800 to $999                     740,595
# 4          $1,000 to $1,499                   2,075,357
# 5          $1,500 to $1,999                   2,306,916
# 6          $2,000 to $2,499                   1,956,420
# 7          $2,500 to $2,999                   1,400,532
# 8            $3,000 or more                   2,972,450
#
#   2021 Occupied housing units 2020 Occupied housing units  \
# 0                     351,974                     390,873
# 1                     624,760                     682,136
# 2                   1,096,301                   1,164,232
# 3                     779,826                     879,823
# 4                   2,236,265                   2,431,992
# 5                   2,418,761                   2,320,070
# 6                   1,917,161                   1,732,363
# 7                   1,286,733                   1,175,576
# 8                   2,520,134                   2,142,269
#
#   2019 Occupied housing units 2018 Occupied housing units
# 0                     411,198                     411,949
# 1                     697,195                     715,032
# 2                   1,161,935                   1,213,416
# 3                     855,777                     932,008
# 4                   2,404,375                   2,546,448
# 5                   2,364,271                   2,360,982
# 6                   1,757,743                   1,671,244
# 7                   1,194,200                   1,132,604
# 8                   2,136,856                   1,913,169

# %%
monthly_costs_years_df = pd.DataFrame(monthly_costs_years)
monthly_costs_years_df
# Out:
#       MONTHLY HOUSING COSTS 2022 Occupied housing units  \
# 0            Less than $300                     296,456
# 1              $300 to $499                     559,578
# 2              $500 to $799                   1,039,849
# 3              $800 to $999                     740,595
# 4          $1,000 to $1,499                   2,075,357
# 5          $1,500 to $1,999                   2,306,916
# 6          $2,000 to $2,499                   1,956,420
# 7          $2,500 to $2,999                   1,400,532
# 8            $3,000 or more                   2,972,450
#
#   2021 Occupied housing units 2020 Occupied housing units  \
# 0                     351,974                     390,873
# 1                     624,760                     682,136
# 2                   1,096,301                   1,164,232
# 3                     779,826                     879,823
# 4                   2,236,265                   2,431,992
# 5                   2,418,761                   2,320,070
# 6                   1,917,161                   1,732,363
# 7                   1,286,733                   1,175,576
# 8                   2,520,134                   2,142,269
#
#   2019 Occupied housing units 2018 Occupied housing units
# 0                     411,198                     411,949
# 1                     697,195                     715,032
# 2                   1,161,935                   1,213,416
# 3                     855,777                     932,008
# 4                   2,404,375                   2,546,448
# 5                   2,364,271                   2,360,982
# 6                   1,757,743                   1,671,244
# 7                   1,194,200                   1,132,604
# 8                   2,136,856                   1,913,169

# %%
monthly_costs_years_df.set_index('MONTHLY HOUSING COSTS')
# Out:
#                          2022 Occupied housing units  \
# MONTHLY HOUSING COSTS
#         Less than $300                       296,456
#         $300 to $499                         559,578
#         $500 to $799                       1,039,849
#         $800 to $999                         740,595
#         $1,000 to $1,499                   2,075,357
#         $1,500 to $1,999                   2,306,916
#         $2,000 to $2,499                   1,956,420
#         $2,500 to $2,999                   1,400,532
#         $3,000 or more                     2,972,450
#
#                          2021 Occupied housing units  \
# MONTHLY HOUSING COSTS
#         Less than $300                       351,974
#         $300 to $499                         624,760
#         $500 to $799                       1,096,301
#         $800 to $999                         779,826
#         $1,000 to $1,499                   2,236,265
#         $1,500 to $1,999                   2,418,761
#         $2,000 to $2,499                   1,917,161
#         $2,500 to $2,999                   1,286,733
#         $3,000 or more                     2,520,134
#
#                          2020 Occupied housing units  \
# MONTHLY HOUSING COSTS
#         Less than $300                       390,873
#         $300 to $499                         682,136
#         $500 to $799                       1,164,232
#         $800 to $999                         879,823
#         $1,000 to $1,499                   2,431,992
#         $1,500 to $1,999                   2,320,070
#         $2,000 to $2,499                   1,732,363
#         $2,500 to $2,999                   1,175,576
#         $3,000 or more                     2,142,269
#
#                          2019 Occupied housing units  \
# MONTHLY HOUSING COSTS
#         Less than $300                       411,198
#         $300 to $499                         697,195
#         $500 to $799                       1,161,935
#         $800 to $999                         855,777
#         $1,000 to $1,499                   2,404,375
#         $1,500 to $1,999                   2,364,271
#         $2,000 to $2,499                   1,757,743
#         $2,500 to $2,999                   1,194,200
#         $3,000 or more                     2,136,856
#
#                          2018 Occupied housing units
# MONTHLY HOUSING COSTS
#         Less than $300                       411,949
#         $300 to $499                         715,032
#         $500 to $799                       1,213,416
#         $800 to $999                         932,008
#         $1,000 to $1,499                   2,546,448
#         $1,500 to $1,999                   2,360,982
#         $2,000 to $2,499                   1,671,244
#         $2,500 to $2,999                   1,132,604
#         $3,000 or more                     1,913,169

# %%
data = {'2022': [296456, 559578, 1039849, 740595, 2075357, 2306916, 1956420,1400532,2972450], '2021': [351974, 624760, 1096301, 779826, 2236265, 2418761, 1917161, 1286733, 2520134],
        '2020': [390873, 682136, 1164232, 879823, 2431992, 2320070, 1732363, 1175576, 2142269], 
        '2019': [411198, 697195, 1161935, 855777, 2404375, 2364271, 1757743, 1194200,2136853],
        '2018': [411949, 715032, 1213416, 932008, 2546448, 2360982, 1671244, 1132604, 1913169]}
new_df = pd.DataFrame(data, index=['<300', '300 to 499', '500 to 799', '800 to 999', '1000 to 1499', '1500 to 1999', '2000 to 2499', '2500 to 2999', '>3000'])
new_df.index.name = "Monthly Housing Costs"
new_df
# Out:
#                           2022     2021     2020     2019     2018
# Monthly Housing Costs
# <300                    296456   351974   390873   411198   411949
# 300 to 499              559578   624760   682136   697195   715032
# 500 to 799             1039849  1096301  1164232  1161935  1213416
# 800 to 999              740595   779826   879823   855777   932008
# 1000 to 1499           2075357  2236265  2431992  2404375  2546448
# 1500 to 1999           2306916  2418761  2320070  2364271  2360982
# 2000 to 2499           1956420  1917161  1732363  1757743  1671244
# 2500 to 2999           1400532  1286733  1175576  1194200  1132604
# >3000                  2972450  2520134  2142269  2136853  1913169

# %%
new_df.plot()
plt.xticks(rotation=45)
plt.ylabel('# of Housing Units (millions)')
plt.xlabel('Monthly Housing Costs ($)')
plt.show()

# %%
percent_of_income = pd.read_csv('../Brianne/Resources/percentage_of_income.csv')
percent_of_income
# Out:
#   MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME     2022    2021  \
# 0                             Less than 20.0 percent        36.40%  35.70%
# 1                               20.0 to 24.9 percent        14.70%  15.20%
# 2                               25.0 to 29.9 percent        11.10%  11.30%
# 3                               30.0 to 34.9 percent         8.10%   8.10%
# 4                               35.0 percent or more        29.70%  29.60%
#
#      2020    2019    2018
# 0  34.40%  35.10%  34.30%
# 1  15.50%  15.70%  15.30%
# 2  12.00%  12.10%  12.20%
# 3   8.80%   8.60%   8.80%
# 4  29.30%  28.50%  29.40%

# %%
percent_of_income.set_index('MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME ')
# Out:
#                                                       2022    2021    2020  \
# MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOL...
# Less than 20.0 percent                              36.40%  35.70%  34.40%
# 20.0 to 24.9 percent                                14.70%  15.20%  15.50%
# 25.0 to 29.9 percent                                11.10%  11.30%  12.00%
# 30.0 to 34.9 percent                                 8.10%   8.10%   8.80%
# 35.0 percent or more                                29.70%  29.60%  29.30%
#
#                                                       2019    2018
# MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOL...
# Less than 20.0 percent                              35.10%  34.30%
# 20.0 to 24.9 percent                                15.70%  15.30%
# 25.0 to 29.9 percent                                12.10%  12.20%
# 30.0 to 34.9 percent                                 8.60%   8.80%
# 35.0 percent or more                                28.50%  29.40%

# %%
percent_of_income_df = pd.DataFrame(percent_of_income)
percent_of_income_df
# Out:
#   MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME     2022    2021  \
# 0                             Less than 20.0 percent        36.40%  35.70%
# 1                               20.0 to 24.9 percent        14.70%  15.20%
# 2                               25.0 to 29.9 percent        11.10%  11.30%
# 3                               30.0 to 34.9 percent         8.10%   8.10%
# 4                               35.0 percent or more        29.70%  29.60%
#
#      2020    2019    2018
# 0  34.40%  35.10%  34.30%
# 1  15.50%  15.70%  15.30%
# 2  12.00%  12.10%  12.20%
# 3   8.80%   8.60%   8.80%
# 4  29.30%  28.50%  29.40%

# %%
percent_data = {'2018': [34.3, 15.3, 12.2, 8.8, 29.4], '2019': [35.1, 15.7, 12.1, 8.6, 28.5], '2020': [34.3, 15.7, 12.0, 8.6, 29.4],
                '2021': [35.7, 15.2, 11.3, 8.1, 29.6], '2022': [36.4, 14.7, 11.1, 8.1, 29.7]}

percent_df = pd.DataFrame(percent_data, index=['<20%', '20% to 24.9%', '25% to 29.9%', '30% to 34.9%', '>30%'])
percent_df.index.name = "Monthly Housing Costs as Percent of Income"
percent_df
# Out:
#                                             2018  2019  2020  2021  2022
# Monthly Housing Costs as Percent of Income
# <20%                                        34.3  35.1  34.3  35.7  36.4
# 20% to 24.9%                                15.3  15.7  15.7  15.2  14.7
# 25% to 29.9%                                12.2  12.1  12.0  11.3  11.1
# 30% to 34.9%                                 8.8   8.6   8.6   8.1   8.1
# >30%                                        29.4  28.5  29.4  29.6  29.7

# %%
percent_df.plot()
plt.xticks(rotation=45)
plt.ylabel('Percentage of Owners')
plt.xlabel('Percentage of Income')
plt.show()
